# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = ("../Resources/cities.csv")

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 608

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Define variables to hold city data collected - from list below - ("Export the city data into a .csv.")
local_cities = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
temp = []
wind = []

# Initialize city and group index counters
record_index = 0
set_index = 1

# use list of units
units = ["imperial"]

# Save config information - (Burundi lesson)
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# Check on the weather in each city using a series of successive API calls
print("------------------------------")
print("Beginning Data Retrieval")
print("------------------------------")

# loop throught the list of cities and append them to list
for city in cities:
    
    # Build query URL based on current element in units
    query_url = url + "&q=" + city
    
    # Get weather information for each city
    response = requests.get(query_url).json()
    
    if record_index < 50:
        record_index += 1
        
    else:
        set_index += 1
        record_index = 1

    print("Processing record {} of set {} | {}".format(record_index, set_index, city))

    # get weather detailed information for each city and use error wrapper - (MakingExceptions lesson--try/except block)

    try:

        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind.append(response["wind"]["speed"])
        local_cities.append(city)
        
    except:
        print("City not found!")
        pass

print("------------------------------")
print("Data Retrieval Complete")
print("------------------------------")
# Out:
# ------------------------------
# Beginning Data Retrieval
# ------------------------------
# Processing record 1 of set 1 | cabo san lucas
# Processing record 2 of set 1 | zhigansk
# Processing record 3 of set 1 | busselton
# Processing record 4 of set 1 | alofi
# Processing record 5 of set 1 | bhag
# Processing record 6 of set 1 | yellowknife
# Processing record 7 of set 1 | plavinas
# Processing record 8 of set 1 | duldurga
# Processing record 9 of set 1 | torbay
# Processing record 10 of set 1 | cidreira
# Processing record 11 of set 1 | avarua
# Processing record 12 of set 1 | lhokseumawe
# Processing record 13 of set 1 | nabire
# Processing record 14 of set 1 | natal
# Processing record 15 of set 1 | xinqing
# Processing record 16 of set 1 | mar del plata
# Processing record 17 of set 1 | tasiilaq
# Processing record 18 of set 1 | waipawa
# Processing record 19 of set 1 | bredasdorp
# Processing record 20 of set 1 | port elizabeth
# Processing record 21 of set 1 | cockburn town
# Processing record 22 of set 1 | castro
# Processing record 23 of set 1 | albany
# Processing record 24 of set 1 | kapaa
# Processing record 25 of set 1 | kulu
# Processing record 26 of set 1 | hobart
# Processing record 27 of set 1 | atuona
# Processing record 28 of set 1 | prudentopolis
# Processing record 29 of set 1 | ondjiva
# Processing record 30 of set 1 | punta arenas
# Processing record 31 of set 1 | nikolskoye
# Processing record 32 of set 1 | puerto lopez
# City not found!
# Processing record 33 of set 1 | aklavik
# Processing record 34 of set 1 | mataura
# Processing record 35 of set 1 | nizhnyaya omka
# Processing record 36 of set 1 | barentsburg
# City not found!
# Processing record 37 of set 1 | mehamn
# Processing record 38 of set 1 | tomar do geru
# Processing record 39 of set 1 | tuktoyaktuk
# Processing record 40 of set 1 | upernavik
# Processing record 41 of set 1 | ushuaia
# Processing record 42 of set 1 | dawson creek
# Processing record 43 of set 1 | khatanga
# Processing record 44 of set 1 | makakilo city
# Processing record 45 of set 1 | henties bay
# Processing record 46 of set 1 | copiapo
# Processing record 47 of set 1 | yuli
# Processing record 48 of set 1 | geraldton
# Processing record 49 of set 1 | rikitea
# Processing record 50 of set 1 | taolanaro
# City not found!
# Processing record 1 of set 2 | saint-philippe
# Processing record 2 of set 2 | warqla
# City not found!
# Processing record 3 of set 2 | ashqelon
# Processing record 4 of set 2 | tual
# Processing record 5 of set 2 | krasnokamensk
# Processing record 6 of set 2 | hilo
# Processing record 7 of set 2 | skibbereen
# Processing record 8 of set 2 | bethel
# Processing record 9 of set 2 | puerto ayora
# Processing record 10 of set 2 | komsomolskiy
# Processing record 11 of set 2 | santa gertrudes
# Processing record 12 of set 2 | narsaq
# Processing record 13 of set 2 | ukiah
# Processing record 14 of set 2 | yumen
# Processing record 15 of set 2 | havelock
# Processing record 16 of set 2 | isangel
# Processing record 17 of set 2 | rawannawi
# City not found!
# Processing record 18 of set 2 | port alfred
# Processing record 19 of set 2 | tiksi
# Processing record 20 of set 2 | kaitangata
# Processing record 21 of set 2 | along
# Processing record 22 of set 2 | takaungu
# Processing record 23 of set 2 | evensk
# Processing record 24 of set 2 | victoria
# Processing record 25 of set 2 | bolungarvik
# City not found!
# Processing record 26 of set 2 | san policarpo
# Processing record 27 of set 2 | deputatskiy
# Processing record 28 of set 2 | kahului
# Processing record 29 of set 2 | chiang klang
# Processing record 30 of set 2 | itarare
# Processing record 31 of set 2 | srednekolymsk
# Processing record 32 of set 2 | kobryn
# Processing record 33 of set 2 | vila do maio
# Processing record 34 of set 2 | dunedin
# Processing record 35 of set 2 | casa nova
# Processing record 36 of set 2 | portland
# Processing record 37 of set 2 | jamestown
# Processing record 38 of set 2 | leningradskiy
# Processing record 39 of set 2 | qaanaaq
# Processing record 40 of set 2 | port-cartier
# Processing record 41 of set 2 | klaksvik
# Processing record 42 of set 2 | fairbanks
# Processing record 43 of set 2 | rumoi
# Processing record 44 of set 2 | praia
# Processing record 45 of set 2 | thompson
# Processing record 46 of set 2 | zhaoyuan
# Processing record 47 of set 2 | bulgan
# Processing record 48 of set 2 | ramsar
# Processing record 49 of set 2 | ribeira grande
# Processing record 50 of set 2 | gat
# Processing record 1 of set 3 | hamilton
# Processing record 2 of set 3 | tayu
# Processing record 3 of set 3 | marsa matruh
# Processing record 4 of set 3 | grand gaube
# Processing record 5 of set 3 | attawapiskat
# City not found!
# Processing record 6 of set 3 | pevek
# Processing record 7 of set 3 | porto murtinho
# Processing record 8 of set 3 | hithadhoo
# Processing record 9 of set 3 | waingapu
# Processing record 10 of set 3 | adrar
# Processing record 11 of set 3 | vaini
# Processing record 12 of set 3 | east london
# Processing record 13 of set 3 | ketchikan
# Processing record 14 of set 3 | hovd
# Processing record 15 of set 3 | tsihombe
# City not found!
# Processing record 16 of set 3 | kawana waters
# City not found!
# Processing record 17 of set 3 | uyemskiy
# Processing record 18 of set 3 | rocha
# Processing record 19 of set 3 | cape town
# Processing record 20 of set 3 | vaitupu
# City not found!
# Processing record 21 of set 3 | kalomo
# City not found!
# Processing record 22 of set 3 | cumpas
# Processing record 23 of set 3 | ilulissat
# Processing record 24 of set 3 | dikson
# Processing record 25 of set 3 | illoqqortoormiut
# City not found!
# Processing record 26 of set 3 | kodiak
# Processing record 27 of set 3 | bluff
# Processing record 28 of set 3 | butaritari
# Processing record 29 of set 3 | prince rupert
# Processing record 30 of set 3 | hay river
# Processing record 31 of set 3 | lebu
# Processing record 32 of set 3 | volchikha
# Processing record 33 of set 3 | lompoc
# Processing record 34 of set 3 | villa carlos paz
# Processing record 35 of set 3 | saint george
# Processing record 36 of set 3 | aykhal
# Processing record 37 of set 3 | praia da vitoria
# Processing record 38 of set 3 | tres coroas
# Processing record 39 of set 3 | reinosa
# Processing record 40 of set 3 | talakan
# Processing record 41 of set 3 | flinders
# Processing record 42 of set 3 | bathsheba
# Processing record 43 of set 3 | tahoua
# Processing record 44 of set 3 | luderitz
# Processing record 45 of set 3 | muli
# Processing record 46 of set 3 | malwan
# City not found!
# Processing record 47 of set 3 | longyearbyen
# Processing record 48 of set 3 | hermanus
# Processing record 49 of set 3 | pimentel
# Processing record 50 of set 3 | buzuluk
# Processing record 1 of set 4 | norman wells
# Processing record 2 of set 4 | taoudenni
# Processing record 3 of set 4 | grenaa
# Processing record 4 of set 4 | barrow
# Processing record 5 of set 4 | belushya guba
# City not found!
# Processing record 6 of set 4 | oktyabrskoye
# Processing record 7 of set 4 | somerset
# Processing record 8 of set 4 | chokurdakh
# Processing record 9 of set 4 | conceicao do araguaia
# Processing record 10 of set 4 | katsuura
# Processing record 11 of set 4 | vanavara
# Processing record 12 of set 4 | omsukchan
# Processing record 13 of set 4 | kotaparh
# Processing record 14 of set 4 | codrington
# Processing record 15 of set 4 | tsabong
# Processing record 16 of set 4 | saint-louis
# Processing record 17 of set 4 | amderma
# City not found!
# Processing record 18 of set 4 | hasaki
# Processing record 19 of set 4 | bengkulu
# City not found!
# Processing record 20 of set 4 | saskylakh
# Processing record 21 of set 4 | canala
# Processing record 22 of set 4 | lagunillas
# Processing record 23 of set 4 | lavrentiya
# Processing record 24 of set 4 | arraial do cabo
# Processing record 25 of set 4 | inhambane
# Processing record 26 of set 4 | mahajanga
# Processing record 27 of set 4 | saint-georges
# Processing record 28 of set 4 | megion
# Processing record 29 of set 4 | vardo
# Processing record 30 of set 4 | saleaula
# City not found!
# Processing record 31 of set 4 | dongsheng
# Processing record 32 of set 4 | nome
# Processing record 33 of set 4 | cayenne
# Processing record 34 of set 4 | orshanka
# Processing record 35 of set 4 | moose factory
# Processing record 36 of set 4 | corinto
# Processing record 37 of set 4 | mys shmidta
# City not found!
# Processing record 38 of set 4 | jining
# Processing record 39 of set 4 | itamaraca
# Processing record 40 of set 4 | pachino
# Processing record 41 of set 4 | hattiesburg
# Processing record 42 of set 4 | nizhniy baskunchak
# Processing record 43 of set 4 | itarema
# Processing record 44 of set 4 | rusape
# Processing record 45 of set 4 | mount gambier
# Processing record 46 of set 4 | marcona
# City not found!
# Processing record 47 of set 4 | synya
# Processing record 48 of set 4 | cururupu
# Processing record 49 of set 4 | chulym
# Processing record 50 of set 4 | sagauli
# Processing record 1 of set 5 | karratha
# Processing record 2 of set 5 | khor
# Processing record 3 of set 5 | sentyabrskiy
# City not found!
# Processing record 4 of set 5 | banda aceh
# Processing record 5 of set 5 | mahanje
# City not found!
# Processing record 6 of set 5 | lagos
# Processing record 7 of set 5 | roald
# Processing record 8 of set 5 | hohhot
# Processing record 9 of set 5 | shahr-e babak
# Processing record 10 of set 5 | say
# Processing record 11 of set 5 | alice springs
# Processing record 12 of set 5 | grindavik
# Processing record 13 of set 5 | khani
# Processing record 14 of set 5 | ibipeba
# Processing record 15 of set 5 | igarka
# Processing record 16 of set 5 | abhar
# Processing record 17 of set 5 | rafai
# Processing record 18 of set 5 | buqayq
# City not found!
# Processing record 19 of set 5 | molepolole
# Processing record 20 of set 5 | nagua
# Processing record 21 of set 5 | tuatapere
# Processing record 22 of set 5 | gamba
# Processing record 23 of set 5 | chicama
# Processing record 24 of set 5 | lajkovac
# Processing record 25 of set 5 | xuddur
# Processing record 26 of set 5 | new norfolk
# Processing record 27 of set 5 | mchinji
# Processing record 28 of set 5 | andarab
# City not found!
# Processing record 29 of set 5 | louisbourg
# City not found!
# Processing record 30 of set 5 | iqaluit
# Processing record 31 of set 5 | riyadh
# Processing record 32 of set 5 | oranjemund
# Processing record 33 of set 5 | buala
# Processing record 34 of set 5 | souillac
# Processing record 35 of set 5 | boundiali
# Processing record 36 of set 5 | paamiut
# Processing record 37 of set 5 | port hardy
# Processing record 38 of set 5 | mezen
# Processing record 39 of set 5 | san juan
# Processing record 40 of set 5 | palmer
# Processing record 41 of set 5 | poum
# Processing record 42 of set 5 | ponta do sol
# Processing record 43 of set 5 | bandarbeyla
# Processing record 44 of set 5 | belaya gora
# Processing record 45 of set 5 | vostok
# Processing record 46 of set 5 | kavieng
# Processing record 47 of set 5 | sur
# Processing record 48 of set 5 | carnarvon
# Processing record 49 of set 5 | eskilstuna
# Processing record 50 of set 5 | georgetown
# Processing record 1 of set 6 | lethem
# Processing record 2 of set 6 | sioux lookout
# Processing record 3 of set 6 | faanui
# Processing record 4 of set 6 | bozoum
# Processing record 5 of set 6 | avera
# Processing record 6 of set 6 | san patricio
# Processing record 7 of set 6 | benjamin constant
# Processing record 8 of set 6 | tarbagatay
# Processing record 9 of set 6 | severo-kurilsk
# Processing record 10 of set 6 | kiruna
# Processing record 11 of set 6 | satitoa
# City not found!
# Processing record 12 of set 6 | cotonou
# Processing record 13 of set 6 | cherskiy
# Processing record 14 of set 6 | nampula
# Processing record 15 of set 6 | nzerekore
# Processing record 16 of set 6 | saldanha
# Processing record 17 of set 6 | nalut
# Processing record 18 of set 6 | saint-pierre
# Processing record 19 of set 6 | la ronge
# Processing record 20 of set 6 | constitucion
# Processing record 21 of set 6 | mananara
# City not found!
# Processing record 22 of set 6 | santa cruz
# Processing record 23 of set 6 | dingle
# Processing record 24 of set 6 | namibe
# Processing record 25 of set 6 | kiunga
# Processing record 26 of set 6 | padang
# Processing record 27 of set 6 | bambous virieux
# Processing record 28 of set 6 | chuy
# Processing record 29 of set 6 | wulanhaote
# City not found!
# Processing record 30 of set 6 | risor
# Processing record 31 of set 6 | ruatoria
# City not found!
# Processing record 32 of set 6 | kudamatsu
# Processing record 33 of set 6 | hammerfest
# Processing record 34 of set 6 | kampot
# Processing record 35 of set 6 | tubuala
# Processing record 36 of set 6 | saint anthony
# Processing record 37 of set 6 | bitburg
# Processing record 38 of set 6 | sosnovo-ozerskoye
# Processing record 39 of set 6 | korla
# City not found!
# Processing record 40 of set 6 | cumaribo
# City not found!
# Processing record 41 of set 6 | mogadishu
# Processing record 42 of set 6 | karkaralinsk
# City not found!
# Processing record 43 of set 6 | cam ranh
# Processing record 44 of set 6 | rio gallegos
# Processing record 45 of set 6 | jalu
# Processing record 46 of set 6 | arman
# Processing record 47 of set 6 | qasigiannguit
# Processing record 48 of set 6 | devarkonda
# Processing record 49 of set 6 | the pas
# Processing record 50 of set 6 | nerja
# Processing record 1 of set 7 | flin flon
# Processing record 2 of set 7 | airai
# Processing record 3 of set 7 | ufa
# Processing record 4 of set 7 | yeppoon
# Processing record 5 of set 7 | hunza
# City not found!
# Processing record 6 of set 7 | bilibino
# Processing record 7 of set 7 | kangaatsiaq
# Processing record 8 of set 7 | salalah
# Processing record 9 of set 7 | kysyl-syr
# Processing record 10 of set 7 | guaymas
# Processing record 11 of set 7 | lotofaga
# Processing record 12 of set 7 | rognan
# Processing record 13 of set 7 | chakulia
# Processing record 14 of set 7 | spirit river
# Processing record 15 of set 7 | sarkand
# Processing record 16 of set 7 | berlevag
# Processing record 17 of set 7 | killybegs
# Processing record 18 of set 7 | eureka
# Processing record 19 of set 7 | beatrice
# Processing record 20 of set 7 | quatre cocos
# Processing record 21 of set 7 | ostrovnoy
# Processing record 22 of set 7 | tumannyy
# City not found!
# Processing record 23 of set 7 | mackay
# Processing record 24 of set 7 | rochelle
# Processing record 25 of set 7 | salinopolis
# Processing record 26 of set 7 | sorong
# Processing record 27 of set 7 | sungai siput utara
# City not found!
# Processing record 28 of set 7 | leshukonskoye
# Processing record 29 of set 7 | gao
# Processing record 30 of set 7 | balikpapan
# Processing record 31 of set 7 | tavda
# Processing record 32 of set 7 | bereda
# Processing record 33 of set 7 | lagoa
# Processing record 34 of set 7 | berezniki
# Processing record 35 of set 7 | college
# Processing record 36 of set 7 | harper
# Processing record 37 of set 7 | port lincoln
# Processing record 38 of set 7 | sao paulo de olivenca
# Processing record 39 of set 7 | kavaratti
# Processing record 40 of set 7 | narayanganj
# Processing record 41 of set 7 | palabuhanratu
# City not found!
# Processing record 42 of set 7 | provideniya
# Processing record 43 of set 7 | huambo
# Processing record 44 of set 7 | shangrao
# Processing record 45 of set 7 | esperance
# Processing record 46 of set 7 | rungata
# City not found!
# Processing record 47 of set 7 | plettenberg bay
# Processing record 48 of set 7 | umm kaddadah
# Processing record 49 of set 7 | anadyr
# Processing record 50 of set 7 | naukot
# Processing record 1 of set 8 | tutoia
# Processing record 2 of set 8 | cherkasskoye
# Processing record 3 of set 8 | kawalu
# Processing record 4 of set 8 | nizhneyansk
# City not found!
# Processing record 5 of set 8 | guerrero negro
# Processing record 6 of set 8 | tarko-sale
# Processing record 7 of set 8 | manakara
# Processing record 8 of set 8 | jember
# Processing record 9 of set 8 | abu dhabi
# Processing record 10 of set 8 | omboue
# Processing record 11 of set 8 | moerai
# Processing record 12 of set 8 | ixtapa
# Processing record 13 of set 8 | sakakah
# City not found!
# Processing record 14 of set 8 | eyrarbakki
# Processing record 15 of set 8 | pisco
# Processing record 16 of set 8 | tabuk
# Processing record 17 of set 8 | mahebourg
# Processing record 18 of set 8 | sola
# Processing record 19 of set 8 | hirado
# Processing record 20 of set 8 | los llanos de aridane
# Processing record 21 of set 8 | san jeronimo
# Processing record 22 of set 8 | biak
# Processing record 23 of set 8 | chapais
# Processing record 24 of set 8 | necochea
# Processing record 25 of set 8 | falealupo
# City not found!
# Processing record 26 of set 8 | svobodnyy
# Processing record 27 of set 8 | keti bandar
# Processing record 28 of set 8 | puerto maldonado
# Processing record 29 of set 8 | vao
# Processing record 30 of set 8 | cockburn harbour
# City not found!
# Processing record 31 of set 8 | cap malheureux
# Processing record 32 of set 8 | codajas
# Processing record 33 of set 8 | saint petersburg
# Processing record 34 of set 8 | sugito
# Processing record 35 of set 8 | muros
# Processing record 36 of set 8 | umm lajj
# Processing record 37 of set 8 | verkhnetulomskiy
# Processing record 38 of set 8 | berdigestyakh
# Processing record 39 of set 8 | pavlohrad
# Processing record 40 of set 8 | caravelas
# Processing record 41 of set 8 | reconquista
# Processing record 42 of set 8 | kuching
# Processing record 43 of set 8 | laguna
# Processing record 44 of set 8 | atka
# City not found!
# Processing record 45 of set 8 | winslow
# Processing record 46 of set 8 | elesbao veloso
# Processing record 47 of set 8 | high level
# Processing record 48 of set 8 | zelenoborsk
# Processing record 49 of set 8 | tessalit
# Processing record 50 of set 8 | tabou
# Processing record 1 of set 9 | aasiaat
# Processing record 2 of set 9 | vila franca do campo
# Processing record 3 of set 9 | ocozocoautla
# City not found!
# Processing record 4 of set 9 | izhma
# Processing record 5 of set 9 | norman
# Processing record 6 of set 9 | treia
# Processing record 7 of set 9 | dandong
# Processing record 8 of set 9 | husavik
# Processing record 9 of set 9 | kruisfontein
# Processing record 10 of set 9 | bonthe
# Processing record 11 of set 9 | buenos aires
# Processing record 12 of set 9 | tigzirt
# Processing record 13 of set 9 | aligudarz
# Processing record 14 of set 9 | nagato
# Processing record 15 of set 9 | twin falls
# Processing record 16 of set 9 | yulara
# Processing record 17 of set 9 | toliary
# City not found!
# Processing record 18 of set 9 | kununurra
# Processing record 19 of set 9 | estelle
# Processing record 20 of set 9 | moba
# Processing record 21 of set 9 | samarai
# Processing record 22 of set 9 | lunenburg
# Processing record 23 of set 9 | richards bay
# Processing record 24 of set 9 | beringovskiy
# Processing record 25 of set 9 | krasnoselkup
# City not found!
# Processing record 26 of set 9 | zyryanka
# Processing record 27 of set 9 | dzhusaly
# City not found!
# Processing record 28 of set 9 | awbari
# Processing record 29 of set 9 | clyde river
# Processing record 30 of set 9 | sindou
# Processing record 31 of set 9 | pimenta bueno
# Processing record 32 of set 9 | denpasar
# Processing record 33 of set 9 | tezpur
# Processing record 34 of set 9 | seybaplaya
# Processing record 35 of set 9 | arcata
# Processing record 36 of set 9 | north bend
# Processing record 37 of set 9 | sadovoye
# Processing record 38 of set 9 | talnakh
# Processing record 39 of set 9 | morden
# Processing record 40 of set 9 | novikovo
# Processing record 41 of set 9 | ancud
# Processing record 42 of set 9 | presidencia roque saenz pena
# Processing record 43 of set 9 | lakes entrance
# Processing record 44 of set 9 | kaoma
# Processing record 45 of set 9 | san juan de uraba
# Processing record 46 of set 9 | port-gentil
# Processing record 47 of set 9 | promyshlennaya
# Processing record 48 of set 9 | san quintin
# Processing record 49 of set 9 | chistogorskiy
# Processing record 50 of set 9 | sahrak
# City not found!
# Processing record 1 of set 10 | pangnirtung
# Processing record 2 of set 10 | sisimiut
# Processing record 3 of set 10 | jinka
# Processing record 4 of set 10 | manokwari
# Processing record 5 of set 10 | kurumkan
# Processing record 6 of set 10 | sankt veit
# Processing record 7 of set 10 | botwood
# Processing record 8 of set 10 | worthington
# Processing record 9 of set 10 | houma
# Processing record 10 of set 10 | tambura
# City not found!
# Processing record 11 of set 10 | puerto cabezas
# Processing record 12 of set 10 | shawnee
# Processing record 13 of set 10 | itoman
# Processing record 14 of set 10 | dicabisagan
# Processing record 15 of set 10 | barabash
# Processing record 16 of set 10 | angoche
# Processing record 17 of set 10 | basoko
# Processing record 18 of set 10 | sechura
# Processing record 19 of set 10 | merauke
# Processing record 20 of set 10 | ambulu
# Processing record 21 of set 10 | yanchukan
# City not found!
# Processing record 22 of set 10 | asyut
# Processing record 23 of set 10 | acarau
# City not found!
# Processing record 24 of set 10 | araxa
# Processing record 25 of set 10 | varhaug
# Processing record 26 of set 10 | jardim
# Processing record 27 of set 10 | beloha
# Processing record 28 of set 10 | luzilandia
# Processing record 29 of set 10 | waw
# City not found!
# Processing record 30 of set 10 | antofagasta
# Processing record 31 of set 10 | kitui
# Processing record 32 of set 10 | ghanzi
# Processing record 33 of set 10 | sistranda
# Processing record 34 of set 10 | boli
# Processing record 35 of set 10 | port huron
# Processing record 36 of set 10 | kariba
# Processing record 37 of set 10 | taybad
# Processing record 38 of set 10 | dubbo
# Processing record 39 of set 10 | grand river south east
# City not found!
# Processing record 40 of set 10 | lovozero
# Processing record 41 of set 10 | murray bridge
# Processing record 42 of set 10 | qaqortoq
# Processing record 43 of set 10 | fortuna
# Processing record 44 of set 10 | batamshinskiy
# Processing record 45 of set 10 | morehead
# Processing record 46 of set 10 | bonavista
# Processing record 47 of set 10 | murgab
# Processing record 48 of set 10 | port keats
# Processing record 49 of set 10 | kamenka
# Processing record 50 of set 10 | naze
# Processing record 1 of set 11 | camacha
# Processing record 2 of set 11 | gualeguay
# Processing record 3 of set 11 | kokuy
# Processing record 4 of set 11 | sitka
# Processing record 5 of set 11 | jawhar
# Processing record 6 of set 11 | athabasca
# Processing record 7 of set 11 | aketi
# Processing record 8 of set 11 | non thai
# Processing record 9 of set 11 | bakchar
# Processing record 10 of set 11 | linshu
# City not found!
# Processing record 11 of set 11 | chagda
# City not found!
# Processing record 12 of set 11 | jian
# Processing record 13 of set 11 | kapit
# Processing record 14 of set 11 | hays
# Processing record 15 of set 11 | invermere
# Processing record 16 of set 11 | salinas
# Processing record 17 of set 11 | atar
# Processing record 18 of set 11 | coos bay
# Processing record 19 of set 11 | aberdeen
# Processing record 20 of set 11 | mutare
# Processing record 21 of set 11 | todos santos
# Processing record 22 of set 11 | nusaybin
# Processing record 23 of set 11 | ternate
# Processing record 24 of set 11 | olafsvik
# City not found!
# Processing record 25 of set 11 | solnechnyy
# Processing record 26 of set 11 | shangqiu
# Processing record 27 of set 11 | tidore
# City not found!
# Processing record 28 of set 11 | litoral del san juan
# City not found!
# Processing record 29 of set 11 | ranfurly
# Processing record 30 of set 11 | hofn
# Processing record 31 of set 11 | astoria
# Processing record 32 of set 11 | marzuq
# Processing record 33 of set 11 | mapiri
# Processing record 34 of set 11 | huai thalaeng
# Processing record 35 of set 11 | stara synyava
# Processing record 36 of set 11 | havre-saint-pierre
# Processing record 37 of set 11 | amahai
# Processing record 38 of set 11 | krasnyy chikoy
# Processing record 39 of set 11 | orlik
# Processing record 40 of set 11 | borgo san lorenzo
# Processing record 41 of set 11 | bud
# Processing record 42 of set 11 | imbituba
# Processing record 43 of set 11 | pacific grove
# Processing record 44 of set 11 | ngukurr
# City not found!
# Processing record 45 of set 11 | tuskegee
# Processing record 46 of set 11 | erzin
# Processing record 47 of set 11 | broken hill
# Processing record 48 of set 11 | lincoln
# Processing record 49 of set 11 | okhotsk
# Processing record 50 of set 11 | huarmey
# Processing record 1 of set 12 | half moon bay
# Processing record 2 of set 12 | marienburg
# Processing record 3 of set 12 | hambantota
# Processing record 4 of set 12 | port augusta
# Processing record 5 of set 12 | erenhot
# Processing record 6 of set 12 | manga
# Processing record 7 of set 12 | puerto del rosario
# Processing record 8 of set 12 | griffith
# Processing record 9 of set 12 | chavakkad
# Processing record 10 of set 12 | asosa
# Processing record 11 of set 12 | the valley
# Processing record 12 of set 12 | aksu
# Processing record 13 of set 12 | mubende
# Processing record 14 of set 12 | kamenskoye
# City not found!
# Processing record 15 of set 12 | bhabua
# Processing record 16 of set 12 | dossor
# Processing record 17 of set 12 | sanghar
# Processing record 18 of set 12 | opobo
# City not found!
# Processing record 19 of set 12 | kieta
# Processing record 20 of set 12 | boguchany
# Processing record 21 of set 12 | manoel urbano
# Processing record 22 of set 12 | tiarei
# Processing record 23 of set 12 | west wendover
# Processing record 24 of set 12 | whitianga
# Processing record 25 of set 12 | aksarka
# Processing record 26 of set 12 | kristiinankaupunki
# City not found!
# Processing record 27 of set 12 | santa lucia
# Processing record 28 of set 12 | malpe
# Processing record 29 of set 12 | gwanda
# Processing record 30 of set 12 | niquelandia
# Processing record 31 of set 12 | porto walter
# Processing record 32 of set 12 | majene
# Processing record 33 of set 12 | caiaponia
# Processing record 34 of set 12 | iracoubo
# Processing record 35 of set 12 | umzimvubu
# City not found!
# Processing record 36 of set 12 | bitung
# Processing record 37 of set 12 | dakoro
# Processing record 38 of set 12 | ksenyevka
# City not found!
# Processing record 39 of set 12 | cuorgne
# Processing record 40 of set 12 | vuktyl
# Processing record 41 of set 12 | port hedland
# Processing record 42 of set 12 | bundaberg
# Processing record 43 of set 12 | balaka
# Processing record 44 of set 12 | lorengau
# Processing record 45 of set 12 | kautokeino
# Processing record 46 of set 12 | sampit
# Processing record 47 of set 12 | sumkino
# Processing record 48 of set 12 | truckee
# Processing record 49 of set 12 | broome
# Processing record 50 of set 12 | camiri
# Processing record 1 of set 13 | thaba-tseka
# Processing record 2 of set 13 | sibolga
# Processing record 3 of set 13 | general roca
# Processing record 4 of set 13 | samusu
# City not found!
# Processing record 5 of set 13 | pilar
# Processing record 6 of set 13 | thinadhoo
# Processing record 7 of set 13 | zarand
# Processing record 8 of set 13 | rudnogorsk
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Export the city data into a .csv - cities, cloudiness, country, date, humidity, lat/lng, temperature  and wind speed
# lesson: PANDAS 4.1.03 creating_data_frames 11-26-2019

city_weather = {
    "City": local_cities,
    "Cloudiness" : cloudiness,
    "Country" : country,
    "Date" : date,
    "Humidity" : humidity,
    "Max Temp": temp,    
    "Lat" : lat,
    "Lng" : lng,  
    "Wind Speed" : wind
}


# Create the dataframe
city_weather_df = pd.DataFrame(city_weather)

# save the dataframe into a .csv file
city_weather_df.to_csv("../Resources/weather-across-the-globe.csv")
                       

# Display the dataframe
city_weather_df.count()
# Out:
# City          545
# Cloudiness    545
# Country       545
# Date          545
# Humidity      545
# Max Temp      545
# Lat           545
# Lng           545
# Wind Speed    545
# dtype: int64

# %%
# Display a sampling of weather in cities across the globe
city_weather_df.head()
# Out:
#              City  Cloudiness Country        Date  Humidity  Max Temp    Lat  \
# 0  cabo san lucas          20      MX  1578335333        50     75.99  22.89
# 1        zhigansk         100      RU  1578335434        95     -2.42  66.77
# 2       busselton           7      AU  1578335434        27     64.99 -33.64
# 3           alofi          75      NU  1578335434        94     77.00 -19.06
# 4            bhag          93      PK  1578335434        85     53.51  29.04
#
#       Lng  Wind Speed
# 0 -109.91        4.18
# 1  123.37       21.63
# 2  115.35       10.89
# 3 -169.92        3.36
# 4   67.82        5.32

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# City Latitude vs Max Temperature
plt.scatter(city_weather_df["Lat"], city_weather_df["Max Temp"], marker="o", edgecolors="black", facecolors="darkturquoise")

# Format the plot title and axis labels
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Max temperature (°F)")
plt.grid()

# save the image in a .png file
plt.savefig("../Images/CityLatitudeVsMaxTemperature.png")

#Display the graph
plt.show()

# %% [raw]
# Code Analysis: City Latitude vs. Max Temperature
# The code generates a scatter graph that shows the location of cities in the sample and the associated maximum recorded temperatures.
# The chart shows a direct correlation between the location of a city (latitude) and the maximum temperature on record.
# On the extreme ends of recorded maximum temperature, there are fewer cities exceeding a heat index of 100 degrees fahrenheit,
#         and all of them are located below the equator; whereas the cities experiencing freezing temperatures of below 32
#         degrees are all located north of the equator.
#  There is a clustering of cities in this sample, that are situated between latitude -20 (south of equator)
#         to latitude 40 (north of equator) that enjoy maximum temperatures ranging from 45 to 80 degrees fahrenheit.
#  A caveat as more analysis is presented below, is to keep in mind the land mass distribution on the north and
#         the south of the equator.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# City Latitude vs Humidity
plt.scatter(city_weather_df["Lat"], city_weather_df["Humidity"], marker="o", edgecolors="black", facecolors="darkturquoise")

# Format the plot title and axis labels
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()

# save the image in a .png file
plt.savefig("../Images/CityLatitudeVsHumidity.png")

#Display the graph
plt.show()

# %% [raw]
# Code Analysis: City Latitude vs. Humidity
# The code written for this analysis closely resembles the code used to generate the first chart on maximum temperatures.
# The comparison chart generated above, between location and humidity levels show marked differences
#     based on city location in the globe.
# Considering an ideal humidity range of 45% to 55%,  there are a few cities in the world with this condition and
#     they are widely distributed.
# Most of the cities in this sample have a recorded high humidity of over 70%, and more humid cities are located
#     north of the equator.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# City Latitude vs Cloudiness
city_weather_df.plot(kind="scatter", x="Lat", y="Cloudiness", marker="o", edgecolors="black",facecolors="darkturquoise")

# Format the plot title and axis labels
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()

# save the image in a .png file
plt.savefig("../Images/LatitudeVsCloudiness.png")

#Display the graph
plt.show()

# %%
Code Analysis: City Latitude vs. Cloudiness
The code written for this analysis closely resembles the code used to generate the first chart on maximum temperatures.
The comparison chart generated above, between location and cloudiness condition show wide dispersion
    based on city location in the globe, even considering conditions of extreme cloudiness and zero cloudiness.
If bright skies are a pre-condition to visiting a city, there are may cities in this sample that have levels
    of cloudiness that are 20% or below. Break out the suntan lotion!

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# City Latitude vs Wind Speed
city_weather_df.plot(kind="scatter", x="Lat", y="Wind Speed", marker="o", edgecolors="black",facecolors="darkturquoise")

# Format the plot title and axis labels
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()

# save the image in a .png file
plt.savefig("../Images/CityLatitudeVsWindSpeed.png")

#Display the graph
plt.show()

# %%
Code Analysis: City Latitude vs. Wind Speed
The code written for this analysis closely resembles the code used to generate the first chart on maximum temperatures.
The comparison chart generated above, show most cities have wind speeds falling below 10 mph, and a majority having wind sppeds
    below 15 mph.
There are a few outlier cities where wind gust to over 25 mph and where skirts, hats and toupees are best secured tightly.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

## Convert to floats and store Latitude and Max Temperature as x and y values
x_values = city_weather_df["Lat"].astype("float")
y_values = city_weather_df["Max Temp"].astype("float")

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-40,-20),fontsize=15,color="red")

# Label plot
plt.title("All Hemispheres: Max Temp vs. Latitude Linear Regression (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Max Temp")

# Print r square value
print(f"The r-squared is: {rvalue}")

# Show plot
plt.show()
# Out:
# The r-squared is: -0.7911039231282184

# %%
# Set data *******************
# Create dataframe of cities by hemisphhere
# Northern Hemisphere:
northern_cities = (city_weather_df["Lat"].astype("float") >= 0)
northern_cities_df = city_weather_df[northern_cities] 

# Southern Hemisphere:
southern_cities = (city_weather_df["Lat"].astype("float") < 0)
southern_cities_df = city_weather_df[Southern_cities]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
## Convert to floats and store Latitude and Max Temperature as x and y values
x_values = northern_cities_df["Lat"].astype("float")
y_values = northern_cities_df["Max Temp"].astype("float")

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,-30),fontsize=20,color="red")

# Label plot
plt.title("Northern Hemisphere: Max Temp vs. Latitude Linear Regression (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Max Temp")

# Print r square value
print(f"The r-squared is: {rvalue}")

# Show plot
plt.show()
# Out:
# The r-squared is: -0.8638204451426208

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
## Convert to floats and store Latitude and Max Temperature as x and y values
x_values = southern_cities_df["Lat"].astype("float")
y_values = southern_cities_df["Max Temp"].astype("float")

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-35,45),fontsize=20,color="red")

# Label plot
plt.title("Southern Hemisphere: Max Temp vs. Latitude Linear Regression (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Max Temp")

# Print r square value
print(f"The r-squared is: {rvalue}")

# Show plot
plt.show()
# Out:
# The r-squared is: 0.5153036434532778

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
## Convert to floats and store Latitude and Humidity as x and y values
x_values = northern_cities_df["Lat"].astype("float")
y_values = northern_cities_df["Humidity"].astype("float")

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(33,12),fontsize=20,color="red")

# Label plot
plt.title("Northern Hemisphere: Humidity vs. Latitude Linear Regression (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Humidity")

# Print r square value
print(f"The r-squared is: {rvalue}")

# Show plot
plt.show()
# Out:
# The r-squared is: 0.3995074281681854

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
## Convert to floats and store Latitude and Humidity as x and y values
x_values = southern_cities_df["Lat"].astype("float")
y_values = southern_cities_df["Humidity"].astype("float")

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-31, 12),fontsize=20,color="red")

# Label plot
plt.title("Southern Hemisphere: Humidity vs. Latitude Linear Regression (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Humidity")

# Print r square value
print(f"The r-squared is: {rvalue}")

# Show plot
plt.show()
# Out:
# The r-squared is: 0.22415502075348365

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
## Convert to floats and store Latitude and Cloudiness as x and y values
x_values = northern_cities_df["Lat"].astype("float")
y_values = northern_cities_df["Cloudiness"].astype("float")

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(27,10),fontsize=14,color="red")

# Label plot
plt.title("Northern Hemisphere: Cloudiness vs. Latitude Linear Regression (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Print r square value
print(f"The r-squared is: {rvalue}")

# Show plot
plt.show()
# Out:
# The r-squared is: 0.19044716920703939

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
## Convert to floats and store Latitude and Cloudiness as x and y values
x_values = southern_cities_df["Lat"].astype("float")
y_values = southern_cities_df["Cloudiness"].astype("float")

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-56, 22),fontsize=15,color="red")

# Label plot
plt.title("Southern Hemisphere: Cloudiness vs. Latitude Linear Regression (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Print r square value
print(f"The r-squared is: {rvalue}")

# Show plot
plt.show()
# Out:
# The r-squared is: 0.11184964020243567

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
## Convert to floats and store Latitude and  Wind Speed as x and y values
x_values = northern_cities_df["Lat"].astype("float")
y_values = northern_cities_df["Wind Speed"].astype("float")

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(7, 35),fontsize=20,color="red")

# Label plot
plt.title("Northern Hemisphere: Wind Speed (mph) vs. Latitude Linear Regression (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Print r square value
print(f"The r-squared is: {rvalue}")

# Show plot
plt.show()
# Out:
# The r-squared is: 0.10987848583237271

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
## Convert to floats and store Latitude and  Wind Speed as x and y values
x_values = southern_cities_df["Lat"].astype("float")
y_values = southern_cities_df["Wind Speed"].astype("float")

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-35, 23),fontsize=20,color="red")

# Label plot
plt.title("Southern Hemisphere: Wind Speed (mph) vs. Latitude Linear Regression (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Print r square value
print(f"The r-squared is: {rvalue}")

# Show plot
plt.show()
# Out:
# The r-squared is: -0.20917092579746407
